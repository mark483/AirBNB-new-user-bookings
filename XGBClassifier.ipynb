# %% [markdown]
# # Airbnb New User Bookings

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading The DataSet

# %%
# Load the data into DataFrames
train_users = pd.read_csv('train_users_2.csv')
test_users = pd.read_csv('test_users.csv')

# %%
print("Number of users in training set =", train_users.shape[0] )
print("Number of users in test set =",test_users.shape[0])
# Out:
# Number of users in training set = 213451
# Number of users in test set = 62096

# %%
train_users.describe(include = 'all')
# Out:
#                 id date_account_created  timestamp_first_active  \
# count       213451               213451            2.134510e+05
# unique      213451                 1634                     NaN
# top     2gywhhthwq           2014-05-13                     NaN
# freq             1                  674                     NaN
# mean           NaN                  NaN            2.013085e+13
# std            NaN                  NaN            9.253717e+09
# min            NaN                  NaN            2.009032e+13
# 25%            NaN                  NaN            2.012123e+13
# 50%            NaN                  NaN            2.013091e+13
# 75%            NaN                  NaN            2.014031e+13
# max            NaN                  NaN            2.014063e+13
#
#        date_first_booking     gender            age signup_method  \
# count               88908     213451  125461.000000        213451
# unique               1976          4            NaN             3
# top            2014-05-22  -unknown-            NaN         basic
# freq                  248      95688            NaN        152897
# mean                  NaN        NaN      49.668335           NaN
# std                   NaN        NaN     155.666612           NaN
# min                   NaN        NaN       1.000000           NaN
# 25%                   NaN        NaN      28.000000           NaN
# 50%                   NaN        NaN      34.000000           NaN
# 75%                   NaN        NaN      43.000000           NaN
# max                   NaN        NaN    2014.000000           NaN
#
#           signup_flow language affiliate_channel affiliate_provider  \
# count   213451.000000   213451            213451             213451
# unique            NaN       25                 8                 18
# top               NaN       en            direct             direct
# freq              NaN   206314            137727             137426
# mean         3.267387      NaN               NaN                NaN
# std          7.637707      NaN               NaN                NaN
# min          0.000000      NaN               NaN                NaN
# 25%          0.000000      NaN               NaN                NaN
# 50%          0.000000      NaN               NaN                NaN
# 75%          0.000000      NaN               NaN                NaN
# max         25.000000      NaN               NaN                NaN
#
#        first_affiliate_tracked signup_app first_device_type first_browser  \
# count                   207386     213451            213451        213451
# unique                       7          4                 9            52
# top                  untracked        Web       Mac Desktop        Chrome
# freq                    109232     182717             89600         63845
# mean                       NaN        NaN               NaN           NaN
# std                        NaN        NaN               NaN           NaN
# min                        NaN        NaN               NaN           NaN
# 25%                        NaN        NaN               NaN           NaN
# 50%                        NaN        NaN               NaN           NaN
# 75%                        NaN        NaN               NaN           NaN
# max                        NaN        NaN               NaN           NaN
#
#        country_destination
# count               213451
# unique                  12
# top                    NDF
# freq                124543
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
test_users.head()
# Out:
#            id date_account_created  timestamp_first_active  \
# 0  5uwns89zht           2014-07-01          20140701000006
# 1  jtl0dijy2j           2014-07-01          20140701000051
# 2  xx0ulgorjt           2014-07-01          20140701000148
# 3  6c6puo6ix0           2014-07-01          20140701000215
# 4  czqhjk3yfe           2014-07-01          20140701000305
#
#    date_first_booking     gender   age signup_method  signup_flow language  \
# 0                 NaN     FEMALE  35.0      facebook            0       en
# 1                 NaN  -unknown-   NaN         basic            0       en
# 2                 NaN  -unknown-   NaN         basic            0       en
# 3                 NaN  -unknown-   NaN         basic            0       en
# 4                 NaN  -unknown-   NaN         basic            0       en
#
#   affiliate_channel affiliate_provider first_affiliate_tracked signup_app  \
# 0            direct             direct               untracked      Moweb
# 1            direct             direct               untracked      Moweb
# 2            direct             direct                  linked        Web
# 3            direct             direct                  linked        Web
# 4            direct             direct               untracked        Web
#
#   first_device_type  first_browser
# 0            iPhone  Mobile Safari
# 1            iPhone  Mobile Safari
# 2   Windows Desktop         Chrome
# 3   Windows Desktop             IE
# 4       Mac Desktop         Safari

# %%
test_users.describe(include = 'all')
# Out:
#                 id date_account_created  timestamp_first_active  \
# count        62096                62096            6.209600e+04
# unique       62096                   92                     NaN
# top     1nig9awllr           2014-07-23                     NaN
# freq             1                 1105                     NaN
# mean           NaN                  NaN            2.014081e+13
# std            NaN                  NaN            8.024585e+07
# min            NaN                  NaN            2.014070e+13
# 25%            NaN                  NaN            2.014072e+13
# 50%            NaN                  NaN            2.014081e+13
# 75%            NaN                  NaN            2.014091e+13
# max            NaN                  NaN            2.014093e+13
#
#         date_first_booking     gender           age signup_method  \
# count                  0.0      62096  33220.000000         62096
# unique                 NaN          4           NaN             4
# top                    NaN  -unknown-           NaN         basic
# freq                   NaN      33792           NaN         45325
# mean                   NaN        NaN     37.616677           NaN
# std                    NaN        NaN     74.440647           NaN
# min                    NaN        NaN      1.000000           NaN
# 25%                    NaN        NaN     26.000000           NaN
# 50%                    NaN        NaN     31.000000           NaN
# 75%                    NaN        NaN     40.000000           NaN
# max                    NaN        NaN   2002.000000           NaN
#
#          signup_flow language affiliate_channel affiliate_provider  \
# count   62096.000000    62096             62096              62096
# unique           NaN       24                 7                 17
# top              NaN       en            direct             direct
# freq             NaN    59224             43844              43844
# mean        7.813885      NaN               NaN                NaN
# std        11.254291      NaN               NaN                NaN
# min         0.000000      NaN               NaN                NaN
# 25%         0.000000      NaN               NaN                NaN
# 50%         0.000000      NaN               NaN                NaN
# 75%        23.000000      NaN               NaN                NaN
# max        25.000000      NaN               NaN                NaN
#
#        first_affiliate_tracked signup_app first_device_type first_browser
# count                    62076      62096             62096         62096
# unique                       7          4                 9            31
# top                  untracked        Web            iPhone     -unknown-
# freq                     33949      37201             19055         17128
# mean                       NaN        NaN               NaN           NaN
# std                        NaN        NaN               NaN           NaN
# min                        NaN        NaN               NaN           NaN
# 25%                        NaN        NaN               NaN           NaN
# 50%                        NaN        NaN               NaN           NaN
# 75%                        NaN        NaN               NaN           NaN
# max                        NaN        NaN               NaN           NaN

# %% [markdown]
# From above, We can see that date_first_booking feature is allways NaN in test dataset so I will remove it from both training and testing.

# %% [markdown]
# ## Data Cleaning

# %%
labels = train_users['country_destination'].values
train_users = train_users.drop(['country_destination', 'date_first_booking'], axis=1)
test_users = test_users.drop(['date_first_booking'], axis=1)
id_test = test_users['id']

# Merge train and test users
all_users = pd.concat((train_users, test_users), axis=0, ignore_index=True)

# Remove ID's since now we are not interested in making predictions
all_users.drop('id',axis=1, inplace=True)

all_users.head()
# Out:
#   date_account_created  timestamp_first_active     gender   age signup_method  \
# 0           2010-06-28          20090319043255  -unknown-   NaN      facebook
# 1           2011-05-25          20090523174809       MALE  38.0      facebook
# 2           2010-09-28          20090609231247     FEMALE  56.0         basic
# 3           2011-12-05          20091031060129     FEMALE  42.0      facebook
# 4           2010-09-14          20091208061105  -unknown-  41.0         basic
#
#    signup_flow language affiliate_channel affiliate_provider  \
# 0            0       en            direct             direct
# 1            0       en               seo             google
# 2            3       en            direct             direct
# 3            0       en            direct             direct
# 4            0       en            direct             direct
#
#   first_affiliate_tracked signup_app first_device_type first_browser
# 0               untracked        Web       Mac Desktop        Chrome
# 1               untracked        Web       Mac Desktop        Chrome
# 2               untracked        Web   Windows Desktop            IE
# 3               untracked        Web       Mac Desktop       Firefox
# 4               untracked        Web       Mac Desktop        Chrome

# %%
from datetime import datetime
all_users['date_account_created'] = pd.to_datetime(all_users['date_account_created'])
all_users['timestamp_first_active'] = pd.to_datetime((all_users.timestamp_first_active // 1000000), format='%Y%m%d')

all_users['date_account_created'] = [datetime.timestamp(d) for d in all_users['date_account_created']]
all_users['timestamp_first_active'] = [datetime.timestamp(d) for d in all_users['timestamp_first_active']]

# %% [markdown]
# the common age to travel is between 14 and 70. So I will smooth Age distribution by remove all values bellow 14 and above 70.

# %%
all_users['age'] = np.where(all_users['age']<=14, 14, all_users['age'])
all_users['age'] = np.where(all_users['age']>=70, 70, all_users['age'])
all_users['age'] = all_users['age'].fillna(all_users['age'].dropna().values.mean())

# %% [markdown]
# ## Feature Engineering

# %%
categorical_features = [
    'affiliate_channel',
    'affiliate_provider',
    'first_affiliate_tracked',
    'first_browser',
    'first_device_type',
    'gender',
    'language',
    'signup_app',
    'signup_method'
]

# one-hot-encoding
for categorical_feature in categorical_features:
    all_users_dummies = pd.get_dummies(all_users[categorical_feature], prefix=categorical_feature)
    all_users = all_users.drop([categorical_feature], axis=1)
    all_users = pd.concat((all_users, all_users_dummies), axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

train_users_n = train_users.shape[0]
X_train = all_users.values[:train_users_n]
le = LabelEncoder()
y_train = le.fit_transform(labels)   
X_test = all_users.values[train_users_n:]

# %%
def generate_answer(y_pred, classifer_name):
    #Taking the 5 classes with highest probabilities
    ids = []  #list of ids
    cts = []  #list of countries
    for i in range(len(id_test)):
        idx = id_test[i]
        ids += [idx] * 5
        cts += le.inverse_transform(np.argsort(y_pred[i])[::-1])[:5].tolist()
    
    sub = pd.DataFrame(np.column_stack((ids, cts)), columns=['id', 'country'])
    sub.to_csv(classifer_name+'.csv',index=False)
    return sub

# %% [markdown]
# ## Classification

# %% [markdown]
# ### XGBClassifier

# %%
from xgboost.sklearn import XGBClassifier

xgb = XGBClassifier(max_depth=6, learning_rate=0.3, n_estimators=25,
                    objective='multi:softprob', subsample=0.5, colsample_bytree=0.5, seed=0)                  
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict_proba(X_test)
generate_answer(y_pred_xgb, 'XGB')
# Out:
#                 id country
# 0       5uwns89zht     NDF
# 1       5uwns89zht      US
# 2       5uwns89zht   other
# 3       5uwns89zht      FR
# 4       5uwns89zht      IT
# ...            ...     ...
# 310475  9uqfg8txu3      US
# 310476  9uqfg8txu3     NDF
# 310477  9uqfg8txu3   other
# 310478  9uqfg8txu3      FR
# 310479  9uqfg8txu3      CA
#
# [310480 rows x 2 columns]
